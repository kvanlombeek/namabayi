# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import sqlite3
# %matplotlib inline
from IPython.core.display import HTML
pd.options.display.max_columns = 50
import seaborn as sb
import datetime
from sqlalchemy import create_engine
import psycopg2
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#sql_conn_local = sqlite3.connect('flask_app/data/analysed_data.sql')
#sql_cursor_local = sql_conn.cursor()
engine_AWS = create_engine('postgresql://%s:%s@forespellpostgis.cusejoju89w7.eu-west-1.rds.amazonaws.com:5432/grb_2016_03' %('kasper', 'VosseM08'))

# %%
#user_id = "FSwWq+h3Hxn+sluX7gADjf4WcLVKpxAt"
sql_conn = create_engine('postgresql://%s:%s@forespellpostgis.cusejoju89w7.eu-west-1.rds.amazonaws.com:5432/grb_2016_03' %('kasper', 'VosseM08'))
#params={'user_id':user_id}
query = '''SELECT *
                FROM feedback '''
feedback = pd.read_sql(sql = query, con=engine_AWS, params = params)
feedback
# Out:
#      feedback          name                        session_id  \
# 0     no_like  Marie-Berthe  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 1     no_like         Geeta  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 2     no_like       Zouhour  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 3     no_like          Chia  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 4     no_like       Devorah  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 5     no_like        Blanda  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 6     no_like        Urania  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 7     no_like        Lurdes  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 8     no_like       Mefaret  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 9     no_like      Césarine  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 10    no_like      Liesette  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 11    no_like    Friederike  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 12    no_like        Janine  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 13    no_like        Olvido  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 14    no_like       Despina  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 15    no_like        Rosane  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 16    no_like         Hlima  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 17    no_like       Catalda  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 18    no_like        Hamama  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 19    no_like          Sati  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 20    no_like       Eduarda  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 21    no_like      Rachella  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 22    no_like         Truda  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 23    no_like        Fridda  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 24    no_like        Rosine  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 25    no_like    Mauricette  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 26    no_like        Aurora  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 27    no_like        Grazia  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 28    no_like         Juana  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# 29    no_like        Fadila  BUzmH3WF8OvxFMzGnrOSo6Ilowvqkt6R
# ...       ...           ...                               ...
# 2544  no_like         Bilal  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2545  no_like         Dante  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2546  no_like         Thijs  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2547  no_like          Remi  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2548  no_like        Yasser  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2549  no_like          Mark  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2550  no_like          Flor  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2551  no_like         Renzo  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2552  no_like         Anwar  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2553  no_like         Jorne  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2554  no_like         Melih  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2555  no_like         Wiebe  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2556  no_like         Youri  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2557  no_like         Timmy  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2558  no_like         Nicky  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2559  no_like         Remko  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2560  no_like         Ferre  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2561  no_like         Yahya  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2562  no_like         Issam  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2563  no_like        Hannes  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2564  no_like        Junior  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2565     like          Vito  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2566  no_like         Samet  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2567  no_like         Kyano  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2568     like         Shaun  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2569     like          Niko  1uWfYUlnjQZa/DzobUizEubw80aSpGqt
# 2570  no_like         Lilya  ybRuEjyIdVbmW6ArXH5INSq43cmKCF6Q
# 2571  no_like       Giorgia  ybRuEjyIdVbmW6ArXH5INSq43cmKCF6Q
# 2572  no_like        Zainab  ybRuEjyIdVbmW6ArXH5INSq43cmKCF6Q
# 2573  no_like         Senna  ybRuEjyIdVbmW6ArXH5INSq43cmKCF6Q
#
#                             time                           user_id sex
# 0     2016-09-01 08:20:32.363714  Y3oH5KYznsVQR0MN5l9qyMcH+t5wFgLI   F
# 1     2016-09-01 08:20:34.269317  Y3oH5KYznsVQR0MN5l9qyMcH+t5wFgLI   F
# 2     2016-09-01 08:20:35.921356  Y3oH5KYznsVQR0MN5l9qyMcH+t5wFgLI   F
# 3     2016-09-01 08:20:37.512176  Y3oH5KYznsVQR0MN5l9qyMcH+t5wFgLI   F
# 4     2016-09-01 08:20:39.338836  Y3oH5KYznsVQR0MN5l9qyMcH+t5wFgLI   F
#
name_lookups.to_sql(con=engine_AWS, name='name_lookups', index=False, if_exists='replace')

# %%
lookups = pd.read_sql('''SELECT * FROM name_lookups LIMIT 100''', con=engine_AWS)
#lookups.columns = [column.lower() for column in lookups.columns]
#lookups.to_sql(name = 'name_lookups', if_exists='replace', index=False, con = engine_AWS)
#lookups
#lookup_names = np.unique(np.append(lookups['name_1'].values,lookups['name_2'].values)).tolist()
#lookup_names.remove('')

# %%
pd.read_sql('''SELECT * FROM feedback''', con=engine_AWS).tail(5)
# Out:
#     feedback     name                        session_id  \
# 439     like    Emile  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 440  no_like  Richard  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 441  no_like    Sasha  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 442  no_like    Diego  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 443  no_like   Alexis  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
#
#                            time                           user_id sex
# 439  2016-09-05 11:50:11.941045  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 440  2016-09-05 11:50:19.174217  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 441  2016-09-05 11:50:54.944717  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 442  2016-09-05 11:51:12.248166  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 443  2016-09-05 11:51:18.306556  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M

# %%
pd.read_sql('''SELECT * FROM sessions''', con=engine_AWS).tail(5)
# Out:
#     ip_address                        session_ID                        time  \
# 333  127.0.0.1  ttCDD+WANqAHGuhwlRURWYX+mvEz0Afk  2016-09-18 17:08:05.412191
# 334  127.0.0.1  ia4CIb19ASzCJW2m70yhuVgy/8vejcpN  2016-09-18 17:08:50.166670
# 335  127.0.0.1  b5cDg8b2SPAe5tLhyxMNCUeQwA3436qK  2016-09-18 17:10:03.835002
# 336  127.0.0.1  E0IcScWf0sQqcglXrMGgMAF6J2XhrYCT  2016-09-18 17:11:02.722404
# 337  127.0.0.1  JwLm6IqN9rP5P+T73l8dpX0fyJtYrF9v  2016-09-18 17:12:35.963271
#
#                               user_ID  \
# 333  3gG4j0QstaS/DoYZfBTQMlCOfcoo7/0G
# 334  gyIivrZNDOiis8mhj7J9nSHeSbeRIEOa
# 335  gyIivrZNDOiis8mhj7J9nSHeSbeRIEOa
# 336  gyIivrZNDOiis8mhj7J9nSHeSbeRIEOa
# 337  gyIivrZNDOiis8mhj7J9nSHeSbeRIEOa
#
#                                             user_agent window_height  \
# 333  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; ...           766
# 334  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...           150
# 335  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...           391
# 336  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...           391
# 337  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...           391
#
#     window_width
# 333         1440
# 334         1280
# 335         1280
# 336         1280
# 337         1280

# %%
feedback = pd.read_sql('''SELECT * FROM feedback''', con=engine_AWS)
feedback.columns = [column.lower() for column in feedback.columns]
feedback.to_sql(con=engine_AWS, name='feedback',index=False, if_exists='replace')

# %%
pd.read_sql('''SELECT * FROM feedback''', con=engine_AWS).tail()
# Out:
#     feedback     name                        session_id  \
# 439     like    Emile  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 440  no_like  Richard  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 441  no_like    Sasha  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 442  no_like    Diego  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
# 443  no_like   Alexis  hMErCykJ4PQyxpKyKcVJZJEajQC5oJWt
#
#                            time                           user_id sex
# 439  2016-09-05 11:50:11.941045  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 440  2016-09-05 11:50:19.174217  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 441  2016-09-05 11:50:54.944717  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 442  2016-09-05 11:51:12.248166  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M
# 443  2016-09-05 11:51:18.306556  wbwCqGiw9/OnompOE6L6vCpIC93t53+U   M

# %%
engine_AWS.execute('''DELETE FROM feedback WHERE time ='F' ''')
